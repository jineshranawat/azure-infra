# %% [markdown]
# # Day 7 — local test notebook
#
# **One-time on any PC:** `cd day7` → `orchestrate.cmd --setup-notebook`
#
# **Kernel (top-right):** pick **FinLedger (.venv)**
#
# If it hangs: click **Select Kernel** → **FinLedger (.venv)** → run cell again.

# %%
channels = ["wire", "card", "fps"]
print("channels:", channels)
print("first:", channels[0])

# %%
import sys
print("Python:", sys.executable)
